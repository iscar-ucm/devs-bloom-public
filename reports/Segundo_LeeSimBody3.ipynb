# %% [markdown]
# Pruebas para leer O2 de BodySim.
# Elimina los FillValues y los Ceros.

# %%
#Pruebas pra añadir la sigma y profundidad
import numpy as np
import netCDF4

filename = '../body/Washington-1d-2008-09-12_compr.nc'
varname = 'WQ_O'
#varname = 'WQ_N'
#varname='WQ_ALG'
#varname = 'Temp'

nc = netCDF4.Dataset(filename)
# File info format HDF5:

# File info
print(nc) # General attributes
print(nc.dimensions)
print(nc.variables.keys()) # All variables names
print(nc.variables) # All variables and their attributes

# Read variables
#   Not all variables have the same dimensions, see file info for details
lat = np.array(nc['lat'])
lon = np.array(nc['lon'])
bottom = np.array(nc['Bottom'])
sigma = np.array(nc['sigma'])
wsel= np.array(nc['WSEL'])
time= np.array(nc['time'])
layers= np.array(nc['layers'])
var= np.array(nc[varname])

# Remove fill values
#   The cells in which no water is present are filled with FillValue
#   Change FillValue to NaN so that those cells don't appear in the plot
inan=lat == nc['lat'].FillValue
lat[inan] = np.nan
lon[inan] = np.nan
bottom[inan]=np.nan
layers[inan]= np.nan
#sigma[sigma== -999]=np.nan   #No tiene FillValue
sigma[sigma>1]=np.nan
sigma[sigma<0]=np.nan
#sigma[sigma== 0]=np.nan
wsel[wsel== nc['WSEL'].FillValue]=np.nan
#wsel[wsel==0]=np.nan
var[var== nc[varname].FillValue]=np.nan
var[var==0] =np.nan
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes): col(78), row(62), cnr(4), lyr(55), time(2881), nalg(1)
#     variables(dimensions): float32 lon(row, col), float32 lat(row, col), float32 lon_bnds(row, col, cnr), float32 lat_bnds(row, col, cnr), float32 layers(row, col), float32 sigma(row, lyr, col), float32 time(time), float32 Bottom(row, col), float32 WSEL(time, row, col), float32 Vx(time, row, col, lyr), float32 Vy(time, row, col, lyr), float32 Vz(time, row, col, lyr), float32 Wx(time, row, col), float32 Wy(time, row, col), float32 Temp(time, row, col, lyr), float32 WQ_ALG(time, row, col, lyr, nalg), float32 WQ_C(time, row, col, lyr), float32 WQ_P(time, row, col, lyr), float32 WQ_N(time, row, col, lyr), float32 WQ_S(time, row, col, lyr), float32 WQ_O(time, row, col, lyr)
#     groups:
# {'col': <class 'netCDF4._netCDF4.Dimension'>: name = 'col', size = 78, 'row': <class 'netCDF4._netCDF4.Dimension'>: name = 'row', size = 62, 'cnr': <class 'netCDF4._netCDF4.Dimension'>: name = 'cnr', size = 4, 'lyr': <class 'netCDF4._netCDF4.Dimension'>: name = 'lyr', size = 55, 'time': <class 'netCDF4._netCDF4.Dimension'>: name = 'time', size = 2881, 'nalg': <class 'netCDF4._netCDF4.Dimension'>: name = 'nalg', size = 1}
# dict_keys(['lon', 'lat', 'lon_bnds', 'lat_bnds', 'layers', 'sigma', 'time', 'Bottom', 'WSEL', 'Vx', 'Vy', 'Vz', 'Wx', 'Wy', 'Temp', 'WQ_ALG', 'WQ_C', 'WQ_P', 'WQ_N', 'WQ_S', 'WQ_O'])
# {'lon': <class 'netCDF4._netCDF4.Variable'>
# float32 lon(row, col)
#     _FillValue: 9.96921e+36
#     standard_name: longitude
#     long_name: longitude at grid cell center
#     units: degrees_east
#     axis: X
#     bounds: lon_bnds
#     projection: geographic
#     FillValue: -999.0
# unlimited dimensions:
# current shape = (62, 78)
# filling on, 'lat': <class 'netCDF4._netCDF4.Variable'>
# float32 lat(row, col)
#     _FillValue: 9.96921e+36
#     standard_name: latitude
#     long_name: latitude at grid cell center
#     units: degrees_north
#     axis: Y
#     bounds: lat_bnds
#     projection: geographic
#     FillValue: -999.0
# unlimited dimensions:
# current shape = (62, 78)
# filling on, 'lon_bnds': <class 'netCDF4._netCDF4.Variable'>
# float32 lon_bnds(row, col, cnr)
#     _FillValue: 9.96921e+36
#     FillValue: -999.0
# unlimited dimensions:
# current shape = (62, 78, 4)
# filling on, 'lat_bnds': <class 'netCDF4._netCDF4.Variable'>
# float32 lat_bnds(row, col, cnr)
#     _FillValue: 9.96921e+36
#     FillValue: -999.0
# unlimited dimensions:
# current shape = (62, 78, 4)
# filling on, 'layers': <class 'netCDF4._netCDF4.Variable'>
# float32 layers(row, col)
#     _FillValue: 9.96921e+36
#     long_name: number of vertical layers
# unlimited dimensions:
# current shape = (62, 78)
# filling on, 'sigma': <class 'netCDF4._netCDF4.Variable'>
# float32 sigma(row, lyr, col)
#     _FillValue: 9.96921e+36
#     standard_name: ocean_sigma_coordinate
#     long_name: sigma at layer midpoints
#     positive: down
#     formula_terms: sigma: lev eta: wsel depth: zbot
# unlimited dimensions:
# current shape = (62, 55, 78)
# filling on, 'time': <class 'netCDF4._netCDF4.Variable'>
# float32 time(time)
#     _FillValue: 9.96921e+36
#     standard_name: time
#     long_name: time
#     units: days since 2005-01-01
#     calendar: julian
# unlimited dimensions:
# current shape = (2881,)
# filling on, 'Bottom': <class 'netCDF4._netCDF4.Variable'>
# float32 Bottom(row, col)
#     _FillValue: 9.96921e+36
#     long_name: bottom bathymetry
#     units: m
#     positive: down
#     grid_mapping: crs
#     coordinates: lat lon
#     FillValue: -999.0
# unlimited dimensions:
# current shape = (62, 78)
# filling on, 'WSEL': <class 'netCDF4._netCDF4.Variable'>
# float32 WSEL(time, row, col)
#     _FillValue: 9.96921e+36
#     long_name: water surface elevation
#     units: m
#     positive: up
#     grid_mapping: crs
#     coordinates: lat lon
#     FillValue: -999.0
# unlimited dimensions:
# current shape = (2881, 62, 78)
# filling on, 'Vx': <class 'netCDF4._netCDF4.Variable'>
# float32 Vx(time, row, col, lyr)
#     _FillValue: 9.96921e+36
#     long_name: eastward flow velocity
#     units: m/s
#     grid_mapping: crs
#     coordinates: lat lon
#     FillValue: -999.0
# unlimited dimensions:
# current shape = (2881, 62, 78, 55)
# filling on, 'Vy': <class 'netCDF4._netCDF4.Variable'>
# float32 Vy(time, row, col, lyr)
#     _FillValue: 9.96921e+36
#     long_name: northward flow velocity
#     units: m/s
#     grid_mapping: crs
#     coordinates: lat lon
#     FillValue: -999.0
# unlimited dimensions:
# current shape = (2881, 62, 78, 55)
# filling on, 'Vz': <class 'netCDF4._netCDF4.Variable'>
# float32 Vz(time, row, col, lyr)
#     _FillValue: 9.96921e+36
#     long_name: upward flow velocity
#     units: m/s
#     grid_mapping: crs
#     coordinates: lat lon
#     FillValue: -999.0
# unlimited dimensions:
# current shape = (2881, 62, 78, 55)
# filling on, 'Wx': <class 'netCDF4._netCDF4.Variable'>
# float32 Wx(time, row, col)
#     _FillValue: 9.96921e+36
#     long_name: Eastward Wind Velocity
#     units: m/s
#     grid_mapping: crs
#     coordinates: lat lon
#     FillValue: -999.0
# unlimited dimensions:
# current shape = (2881, 62, 78)
# filling on, 'Wy': <class 'netCDF4._netCDF4.Variable'>
# float32 Wy(time, row, col)
#     _FillValue: 9.96921e+36
#     long_name: Northward Wind Velocity
#     units: m/s
#     grid_mapping: crs
#     coordinates: lat lon
#     FillValue: -999.0
# unlimited dimensions:
# current shape = (2881, 62, 78)
# filling on, 'Temp': <class 'netCDF4._netCDF4.Variable'>
# float32 Temp(time, row, col, lyr)
#     _FillValue: 9.96921e+36
#     long_name: temperature
#     units: deg.C
#     grid_mapping: crs
#     coordinates: lat lon
#     FillValue: -999.0
# unlimited dimensions:
# current shape = (2881, 62, 78, 55)
# filling on, 'WQ_ALG': <class 'netCDF4._netCDF4.Variable'>
# float32 WQ_ALG(time, row, col, lyr, nalg)
#     _FillValue: 9.96921e+36
#     long_name: Algae
#     units: mg C/L
#     grid_mapping: crs
#     coordinates: lat lon
#     FillValue: -999.0
# unlimited dimensions:
# current shape = (2881, 62, 78, 55, 1)
# filling on, 'WQ_C': <class 'netCDF4._netCDF4.Variable'>
# float32 WQ_C(time, row, col, lyr)
#     _FillValue: 9.96921e+36
#     units: mg/l
#     grid_mapping: crs
#     coordinates: lat lon
#     FillValue: -999.0
#     long_name: Total carbon
# unlimited dimensions:
# current shape = (2881, 62, 78, 55)
# filling on, 'WQ_P': <class 'netCDF4._netCDF4.Variable'>
# float32 WQ_P(time, row, col, lyr)
#     _FillValue: 9.96921e+36
#     units: mg/l
#     grid_mapping: crs
#     coordinates: lat lon
#     FillValue: -999.0
#     long_name: Total phosphorous
# unlimited dimensions:
# current shape = (2881, 62, 78, 55)
# filling on, 'WQ_N': <class 'netCDF4._netCDF4.Variable'>
# float32 WQ_N(time, row, col, lyr)
#     _FillValue: 9.96921e+36
#     units: mg/l
#     grid_mapping: crs
#     coordinates: lat lon
#     FillValue: -999.0
#     long_name: Total nitrogen
# unlimited dimensions:
# current shape = (2881, 62, 78, 55)
# filling on, 'WQ_S': <class 'netCDF4._netCDF4.Variable'>
# float32 WQ_S(time, row, col, lyr)
#     _FillValue: 9.96921e+36
#     units: mg/l
#     grid_mapping: crs
#     coordinates: lat lon
#     FillValue: -999.0
#     long_name: Total silica
# unlimited dimensions:
# current shape = (2881, 62, 78, 55)
# filling on, 'WQ_O': <class 'netCDF4._netCDF4.Variable'>
# float32 WQ_O(time, row, col, lyr)
#     _FillValue: 9.96921e+36
#     units: mg/l
#     grid_mapping: crs
#     coordinates: lat lon
#     FillValue: -999.0
#     long_name: Total oxygen
# unlimited dimensions:
# current shape = (2881, 62, 78, 55)
# filling on}

# %%
# Plots Botton
import matplotlib.pyplot as plt

plt.figure(figsize=(4, 4), dpi=300)
plt.scatter(lon,lat,c=bottom[:,:] , s=5, cmap=plt.cm.jet)
cbar = plt.colorbar()
plt.xlabel('Longitude'), plt.xticks(rotation=30)
plt.ylabel('Latitude')
cbar.set_label('Bottom')
plt.title('Geographic coordinates')
plt.gca().set_aspect('equal')
plt.show()

# %%
#Calculo de profundidad
myt=2
myl=10

rt=range(len(wsel))
ri=range(len(bottom))
rj=range(len(bottom[1]))
rl=range(len(sigma[1]))
#myz = bottom+0
#myz=sigma+0
#mysigma=sigma[:,0,:]

z=np.zeros((len(sigma[1]),len(bottom),len(bottom[1])))
#myz=np.zeros((len(wsel),len(sigma[1]),len(bottom),len(bottom[1])))

for l in rl:
    for i in ri:
        for j in rj:
            sigma[i,l,j]=l/55.0     #Sigma está mal la reconstruyo yo.
            z[l][i][j]=-sigma[i,l,j]*(wsel[myt,i,j] - bottom[i,j])
            #for t in rt:
            #    myz[t][l][i][j]=-sigma[i,l,j]*(wsel[t,i,j] - bottom[i,j])

plt.figure(figsize=(4, 4), dpi=300)
plt.scatter(lon,lat,c=z[myl,:,:] , s=5, cmap=plt.cm.jet)
cbar = plt.colorbar()
plt.xlabel('Longitude'), plt.xticks(rotation=30)
plt.ylabel('Latitude')
cbar.set_label('Depth')
plt.title('Geographic coordinates')
plt.gca().set_aspect('equal')
plt.show()

# %%
#Conseguir una señal a una profundidad en un momento y lugar.
#myt=1000
#mylon=-122.25
#mylat=47.6
mylon=-122.25
mylat=47.7
myz=-10

ind =np.nanargmin(np.sqrt((lat-mylat)*(lat-mylat)+(lon-mylon)*(lon-mylon)))
i=round(ind/len(lon[1]))
j=ind-i*len(lon[1])
myl =np.nanargmin(np.absolute(z[:,i,j]-myz))

print(i,j,myl)
print(lon[i,j],lat[i,j],z[myl,i,j])




#vartl=var[myvar][mytime,:,:,mylayer]
    #latflat = self.vars['lat'][np.logical_not(np.isnan(self.vars['lat']))]
    #lonflat = self.lon[np.logical_not(np.isnan(self.lat))]
#    varflat=vartl[self.vars['inan']]
#    varint=griddata((self.vars['lonflat'], self.vars['latflat']), varflat,(mylon,mylat), method='linear')
# Out:
# 48 -18 12
# -122.24583 47.69945 -10.185388565063477

# %%
# Plots una variable en un moemtio y una capa
#import matplotlib.pyplot as plt
#myt=1500
#mylyr=20
plt.figure(figsize=(4, 4), dpi=300)
plt.scatter(lon,lat,c=var[myt,:,:,myl] , s=5, cmap=plt.cm.jet)
cbar = plt.colorbar()
plt.xlabel('Longitude'), plt.xticks(rotation=30)
plt.ylabel('Latitude')
cbar.set_label(varname)
plt.title('Geographic coordinates')
plt.gca().set_aspect('equal')
plt.show()
